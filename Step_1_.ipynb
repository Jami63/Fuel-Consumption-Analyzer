# %%
import pandas as P

# %%
Data = P.read_csv("Car_Data.csv")

# %%
print(Data.shape)
# Out:
# (550, 12)

# %%
print(Data.columns)
# Out:
# Index(['City MPG', 'Class', 'Combination MPG', 'Cylinders', 'Displacement',
#        'Drive', 'Fuel Type', 'Highway MPG', 'Make', 'Model', 'Transmission',
#        'Year'],
#       dtype='object')

# %%
print(Data.dtypes)
# Out:
# City MPG             int64
# Class               object
# Combination MPG      int64
# Cylinders          float64
# Displacement       float64
# Drive               object
# Fuel Type           object
# Highway MPG          int64
# Make                object
# Model               object
# Transmission        object
# Year                 int64
# dtype: object

# %%
print(Data.describe())
# Out:
#          City MPG  Combination MPG   Cylinders  Displacement  Highway MPG  \
# count  550.000000       550.000000  548.000000    548.000000   550.000000
# mean    21.460000        24.069091    5.315693      2.931752    28.609091
# std      8.147392         7.478369    1.759999      1.248419     6.832228
# min     11.000000        14.000000    3.000000      1.200000    18.000000
# 25%     17.000000        20.000000    4.000000      2.000000    24.000000
# 50%     20.000000        23.000000    4.000000      2.500000    28.000000
# 75%     24.000000        27.000000    6.000000      3.500000    32.000000
# max    126.000000       112.000000   12.000000      6.800000   102.000000
#
#               Year
# count   550.000000
# mean   2019.000000
# std       3.165156
# min    2014.000000
# 25%    2016.000000
# 50%    2019.000000
# 75%    2022.000000
# max    2024.000000

# %%
print(Data.isnull().sum())
# Out:
# City MPG           0
# Class              0
# Combination MPG    0
# Cylinders          2
# Displacement       2
# Drive              0
# Fuel Type          0
# Highway MPG        0
# Make               0
# Model              0
# Transmission       0
# Year               0
# dtype: int64

# %%
print(Data.duplicated().sum())
# Out:
# 2
