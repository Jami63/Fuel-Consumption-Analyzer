# %%
import pandas as P

# %%
Data = P.read_csv("Car_Data_2.csv")

# %%
print(Data.columns)
# Out:
# Index(['Unnamed: 0', 'City MPG', 'Class', 'Combination MPG', 'Cylinders',
#        'Displacement', 'Drive', 'Fuel Type', 'Highway MPG', 'Make', 'Model',
#        'Transmission', 'Year'],
#       dtype='object')

# %%
Data ["Age"] = 2026 - Data ["Year"]

# %%
H = Data[["Age" , "Year"]].head ()

# %%
print(H)
# Out:
#    Age  Year
# 0   12  2014
# 1   12  2014
# 2   12  2014
# 3   12  2014
# 4   12  2014

# %%
I = Data[["Age" , "Year"]].info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 546 entries, 0 to 545
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Age     546 non-null    int64
#  1   Year    546 non-null    int64
# dtypes: int64(2)
# memory usage: 8.7 KB

# %%
print("Info:")
print(I)
# Out:
# Info:
# None

# %%
D = Data[["Age" , "Year"]].describe ()

# %%
print("Describe:")
print(D)
# Out:
# Describe:
#               Age         Year
# count  546.000000   546.000000
# mean     6.979853  2019.020147
# std      3.167721     3.167721
# min      2.000000  2014.000000
# 25%      4.000000  2016.000000
# 50%      7.000000  2019.000000
# 75%     10.000000  2022.000000
# max     12.000000  2024.000000
