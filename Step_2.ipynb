# %%
import pandas as P

# %%
Data = P.read_csv("Car_Data.csv")

# %%
Data = Data.dropna()

# %%
print(Data)
# Out:
#      City MPG                        Class  Combination MPG  Cylinders  \
# 0          25                  midsize car               29        4.0
# 1          26                  midsize car               30        4.0
# 2          25  small sport utility vehicle               27        4.0
# 3          26  small sport utility vehicle               29        4.0
# 4          26  small sport utility vehicle               28        4.0
# ..        ...                          ...              ...        ...
# 545        23                  compact car               27        4.0
# 546        21                  midsize car               24        6.0
# 547        21                  midsize car               24        6.0
# 548        17                  midsize car               19        8.0
# 549        17                  midsize car               19        8.0
#
#      Displacement Drive Fuel Type  Highway MPG   Make  \
# 0             2.5   fwd       gas           36  mazda
# ...

# %%
Data = Data.drop_duplicates()

# %%
print(Data)
# Out:
#      City MPG                        Class  Combination MPG  Cylinders  \
# 0          25                  midsize car               29        4.0
# 1          26                  midsize car               30        4.0
# 2          25  small sport utility vehicle               27        4.0
# 3          26  small sport utility vehicle               29        4.0
# 4          26  small sport utility vehicle               28        4.0
# ..        ...                          ...              ...        ...
# 545        23                  compact car               27        4.0
# 546        21                  midsize car               24        6.0
# 547        21                  midsize car               24        6.0
# 548        17                  midsize car               19        8.0
# 549        17                  midsize car               19        8.0
#
#      Displacement Drive Fuel Type  Highway MPG   Make  \
# 0             2.5   fwd       gas           36  mazda
# ...

# %%
print(Data.columns)
# Out:
# Index(['City MPG', 'Class', 'Combination MPG', 'Cylinders', 'Displacement',
#        'Drive', 'Fuel Type', 'Highway MPG', 'Make', 'Model', 'Transmission',
#        'Year'],
#       dtype='object')

# %%
# Out:
#      City MPG                        Class  Combination MPG  Cylinders  \
# 0          25                  midsize car               29        4.0
# 1          26                  midsize car               30        4.0
# 2          25  small sport utility vehicle               27        4.0
# 3          26  small sport utility vehicle               29        4.0
# 4          26  small sport utility vehicle               28        4.0
# ..        ...                          ...              ...        ...
# 545        23                  compact car               27        4.0
# 546        21                  midsize car               24        6.0
# 547        21                  midsize car               24        6.0
# 548        17                  midsize car               19        8.0
# 549        17                  midsize car               19        8.0
#
#      Displacement Drive Fuel Type  Highway MPG   Make  \
# 0             2.5   FWD       gas           36  mazda
# ...

# %%
Data = Data.copy()

# %%
Data ["Drive"] = Data ["Drive"].str.upper()

# %%
print(Data)
# Out:
#      City MPG                        Class  Combination MPG  Cylinders  \
# 0          25                  midsize car               29        4.0
# 1          26                  midsize car               30        4.0
# 2          25  small sport utility vehicle               27        4.0
# 3          26  small sport utility vehicle               29        4.0
# 4          26  small sport utility vehicle               28        4.0
# ..        ...                          ...              ...        ...
# 545        23                  compact car               27        4.0
# 546        21                  midsize car               24        6.0
# 547        21                  midsize car               24        6.0
# 548        17                  midsize car               19        8.0
# 549        17                  midsize car               19        8.0
#
#      Displacement Drive Fuel Type  Highway MPG   Make  \
# 0             2.5   FWD       gas           36  mazda
# ...

# %%
Data.to_csv("Car_Data_2.csv")
